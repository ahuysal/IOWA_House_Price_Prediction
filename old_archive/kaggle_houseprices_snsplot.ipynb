# %%
import os
import pandas as pd

project_path = 'C:\\Users\\hilmiuysal\\Desktop\\NYC Data Science Academy\\Projects\\Kaggle_HousePrices'
os.chdir(project_path)

train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')


print('Training and test data is loaded')
# Out:
# Training and test data is loaded

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train.sample(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1100  1101          30       RL         60.0     8400   Pave   NaN      Reg
# 493    494          20       RL         70.0     7931   Pave   NaN      Reg
# 357    358         120       RM         44.0     4224   Pave   NaN      Reg
# 155    156          50       RL         60.0     9600   Pave   NaN      Reg
# 973    974          20       FV         95.0    11639   Pave   NaN      Reg
#
#      LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature  \
# 1100         Bnk    AllPub    ...            0    NaN    NaN         NaN
# 493          Lvl    AllPub    ...            0    NaN    NaN         NaN
# 357          Lvl    AllPub    ...            0    NaN  MnPrv         NaN
# 155          Lvl    AllPub    ...            0    NaN    NaN         NaN
# 973          Lvl    AllPub    ...            0    NaN    NaN         NaN
#
#      MiscVal MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
sns.relplot(x='LotArea', y='SalePrice', data=train)

# %%
sns.distplot(train['LotArea'], rug=True)
# Out:
# C:\Users\hilmiuysal\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.kdeplot(train['LotArea'], shade=True)

# %%
sns.jointplot(x="1stFlrSF", y="SalePrice", data=train)

# %%
with sns.axes_style("white"):
    sns.jointplot(x="1stFlrSF", y="SalePrice", kind='hex', color='k', data=train)

# %%
sns.jointplot(x="1stFlrSF", y="SalePrice", kind='kde', data=train)

# %%
train_sub1 = train[['LotFrontage','1stFlrSF','TotalBsmtSF']]
sns.pairplot(train_sub1)
# Out:
# C:\Users\hilmiuysal\Anaconda3\lib\site-packages\numpy\lib\histograms.py:754: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\hilmiuysal\Anaconda3\lib\site-packages\numpy\lib\histograms.py:755: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sns.relplot(x='LotFrontage', y='1stFlrSF', hue='ExterQual', data=train)

# %%
# "point", "bar", "strip", "swarm", "box", "violin", or "boxen"
sns.catplot(x='ExterQual', y='SalePrice', kind='box', hue='CentralAir', order=['Ex','Gd','TA','Fa'], data=train)

# %%
'To put categorical variable on the vertical axis, swap x and y '
sns.catplot(x='SalePrice', y='ExterQual', kind='violin', split=True, hue='CentralAir', order=['Ex','Gd','TA','Fa'], data=train)

# %%
# Facet grid
sns.catplot(x='ExterQual', y='SalePrice', kind='box', hue='CentralAir', order=['Ex','Gd','TA','Fa'], col='Heating', aspect=1, data=train)
